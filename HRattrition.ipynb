# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
dataset = pd.read_csv(r'C:\Users\Melvin Chia\Downloads\archive (4)\WA_Fn-UseC_-HR-Employee-Attrition.csv')

# %%
dataset.head()
# Out:
#    Age Attrition     BusinessTravel  DailyRate              Department  \
# 0   41       Yes      Travel_Rarely       1102                   Sales
# 1   49        No  Travel_Frequently        279  Research & Development
# 2   37       Yes      Travel_Rarely       1373  Research & Development
# 3   33        No  Travel_Frequently       1392  Research & Development
# 4   27        No      Travel_Rarely        591  Research & Development
#
#    DistanceFromHome  Education EducationField  EmployeeCount  EmployeeNumber  \
# 0                 1          2  Life Sciences              1               1
# 1                 8          1  Life Sciences              1               2
# 2                 2          2          Other              1               4
# 3                 3          4  Life Sciences              1               5
# 4                 2          1        Medical              1               7
#
#    ...  RelationshipSatisfaction StandardHours  StockOptionLevel  \
# ...

# %%
dataset.isna().sum()
# Out:
# Age                         0
# Attrition                   0
# BusinessTravel              0
# DailyRate                   0
# Department                  0
# DistanceFromHome            0
# Education                   0
# EducationField              0
# EmployeeCount               0
# EmployeeNumber              0
# EnvironmentSatisfaction     0
# Gender                      0
# HourlyRate                  0
# JobInvolvement              0
# JobLevel                    0
# JobRole                     0
# JobSatisfaction             0
# MaritalStatus               0
# MonthlyIncome               0
# MonthlyRate                 0
# NumCompaniesWorked          0
# Over18                      0
# OverTime                    0
# PercentSalaryHike           0
# PerformanceRating           0
# RelationshipSatisfaction    0
# StandardHours               0
# StockOptionLevel            0
# TotalWorkingYears           0
# TrainingTimesLastYear       0
# WorkLifeBalance             0
# ...

# %% [markdown]
# There are no missing values in the given dataset.

# %%
dataset.nunique()
# Out:
# Age                           43
# Attrition                      2
# BusinessTravel                 3
# DailyRate                    886
# Department                     3
# DistanceFromHome              29
# Education                      5
# EducationField                 6
# EmployeeCount                  1
# EmployeeNumber              1470
# EnvironmentSatisfaction        4
# Gender                         2
# HourlyRate                    71
# JobInvolvement                 4
# JobLevel                       5
# JobRole                        9
# JobSatisfaction                4
# MaritalStatus                  3
# MonthlyIncome               1349
# MonthlyRate                 1427
# NumCompaniesWorked            10
# Over18                         1
# OverTime                       2
# PercentSalaryHike             15
# PerformanceRating              2
# RelationshipSatisfaction       4
# StandardHours                  1
# StockOptionLevel               4
# ...

# %%
print(dataset.dtypes)
dataset.duplicated().sum()
# Out:
# Age                          int64
# Attrition                   object
# BusinessTravel              object
# DailyRate                    int64
# Department                  object
# DistanceFromHome             int64
# Education                    int64
# EducationField              object
# EmployeeCount                int64
# EmployeeNumber               int64
# EnvironmentSatisfaction      int64
# Gender                      object
# HourlyRate                   int64
# JobInvolvement               int64
# JobLevel                     int64
# JobRole                     object
# JobSatisfaction              int64
# MaritalStatus               object
# MonthlyIncome                int64
# MonthlyRate                  int64
# NumCompaniesWorked           int64
# Over18                      object
# OverTime                    object
# PercentSalaryHike            int64
# PerformanceRating            int64
# RelationshipSatisfaction     int64
# StandardHours                int64
# ...

# %% [markdown]
# There is no duplicate data in the given set.

# %%
summary = dataset.describe()

# %%
summary
# Out:
#                Age    DailyRate  DistanceFromHome    Education  EmployeeCount  \
# count  1470.000000  1470.000000       1470.000000  1470.000000         1470.0
# mean     36.923810   802.485714          9.192517     2.912925            1.0
# std       9.135373   403.509100          8.106864     1.024165            0.0
# min      18.000000   102.000000          1.000000     1.000000            1.0
# 25%      30.000000   465.000000          2.000000     2.000000            1.0
# 50%      36.000000   802.000000          7.000000     3.000000            1.0
# 75%      43.000000  1157.000000         14.000000     4.000000            1.0
# max      60.000000  1499.000000         29.000000     5.000000            1.0
#
#        EmployeeNumber  EnvironmentSatisfaction   HourlyRate  JobInvolvement  \
# count     1470.000000              1470.000000  1470.000000     1470.000000
# mean      1024.865306                 2.721769    65.891156        2.729932
# ...

# %% [markdown]
# Looking at the descriptive statistics, there are a few columns that are unlikely to be of any use in the analysis. Hence we will remove them from the dataset.
# These columns are : DailyRate, EmployeeCount,EmployeeNumber,HourlyRate,StandardHours.

# %%
dataset2 = dataset.drop(columns = ['DailyRate','EmployeeCount','EmployeeNumber','HourlyRate','MonthlyRate','EmployeeNumber','StandardHours','Over18'])
dataset2
# Out:
#       Age Attrition     BusinessTravel              Department  \
# 0      41       Yes      Travel_Rarely                   Sales
# 1      49        No  Travel_Frequently  Research & Development
# 2      37       Yes      Travel_Rarely  Research & Development
# 3      33        No  Travel_Frequently  Research & Development
# 4      27        No      Travel_Rarely  Research & Development
# ...   ...       ...                ...                     ...
# 1465   36        No  Travel_Frequently  Research & Development
# 1466   39        No      Travel_Rarely  Research & Development
# 1467   27        No      Travel_Rarely  Research & Development
# 1468   49        No  Travel_Frequently                   Sales
# 1469   34        No      Travel_Rarely  Research & Development
#
#       DistanceFromHome  Education EducationField  EnvironmentSatisfaction  \
# 0                    1          2  Life Sciences                        2
# ...

# %%
Newsummary = dataset2.describe()

# %%
Newsummary
# Out:
#                Age  DistanceFromHome    Education  EnvironmentSatisfaction  \
# count  1470.000000       1470.000000  1470.000000              1470.000000
# mean     36.923810          9.192517     2.912925                 2.721769
# std       9.135373          8.106864     1.024165                 1.093082
# min      18.000000          1.000000     1.000000                 1.000000
# 25%      30.000000          2.000000     2.000000                 2.000000
# 50%      36.000000          7.000000     3.000000                 3.000000
# 75%      43.000000         14.000000     4.000000                 4.000000
# max      60.000000         29.000000     5.000000                 4.000000
#
#        JobInvolvement     JobLevel  JobSatisfaction  MonthlyIncome  \
# count     1470.000000  1470.000000      1470.000000    1470.000000
# mean         2.729932     2.063946         2.728571    6502.931293
# std          0.711561     1.106940         1.102846    4707.956783
# ...

# %%
CorrData = dataset2.corr()

# %%
CorrData
# Out:
#                                Age  DistanceFromHome  Education  \
# Age                       1.000000         -0.001686   0.208034
# DistanceFromHome         -0.001686          1.000000   0.021042
# Education                 0.208034          0.021042   1.000000
# EnvironmentSatisfaction   0.010146         -0.016075  -0.027128
# JobInvolvement            0.029820          0.008783   0.042438
# JobLevel                  0.509604          0.005303   0.101589
# JobSatisfaction          -0.004892         -0.003669  -0.011296
# MonthlyIncome             0.497855         -0.017014   0.094961
# NumCompaniesWorked        0.299635         -0.029251   0.126317
# PercentSalaryHike         0.003634          0.040235  -0.011111
# PerformanceRating         0.001904          0.027110  -0.024539
# RelationshipSatisfaction  0.053535          0.006557  -0.009118
# StockOptionLevel          0.037510          0.044872   0.018422
# TotalWorkingYears         0.680381          0.004628   0.148280
# ...

# %% [markdown]
# In this section, a correlation matrix will be used to identify features that have a strong positive correlation with each other. This will give us a better understanding on how a feature will affect the other features in this dataset.
#
# For example,having a higher job level will result in having higher monthly income. Similarly, having a longer working period in the company also contributed to higher monthly income. Having a higher % in salary hike contributed to higher performance rating of employee.

# %% [markdown]
# Now that we have a slight understanding of the dataset, it is time to delve deeper into employee attritions. Understanding the reasoning behind organization attrition rate. Firstly, lets take a look into the organization profile.

# %%
plt.hist(dataset2['Age'], 10, alpha = 0.6)
plt.xlabel('Age')
plt.ylabel('Number of employees')
plt.title('Age Distribution of IBM employees')
# Out:
# Text(0.5, 1.0, 'Age Distribution of IBM employees')

# %%
GenderCheck = dataset2["Gender"].value_counts().plot(kind = 'pie', autopct = '%.2f')

# %%
AvgMale = dataset2.loc[dataset2['Gender'] == 'Male'].mean()
# Out:
# C:\Users\Melvin Chia\AppData\Local\Temp\ipykernel_18744\2077194954.py:1: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   AvgMale = dataset2.loc[dataset2['Gender'] == 'Male'].mean()

# %%
AvgMale
# Out:
# Age                           36.653061
# DistanceFromHome               9.180272
# Education                      2.899093
# EnvironmentSatisfaction        2.722222
# JobInvolvement                 2.740363
# JobLevel                       2.028345
# JobSatisfaction                2.758503
# MonthlyIncome               6380.507937
# NumCompaniesWorked             2.613379
# PercentSalaryHike             15.217687
# PerformanceRating              3.149660
# RelationshipSatisfaction       2.732426
# StockOptionLevel               0.802721
# TotalWorkingYears             10.981859
# TrainingTimesLastYear          2.758503
# WorkLifeBalance                2.759637
# YearsAtCompany                 6.859410
# YearsInCurrentRole             4.106576
# YearsSinceLastPromotion        2.116780
# YearsWithCurrManager           4.034014
# dtype: float64

# %%
AvgFemale = dataset2.loc[dataset2['Gender'] == 'Female'].mean()
# Out:
# C:\Users\Melvin Chia\AppData\Local\Temp\ipykernel_18744\1981857971.py:1: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   AvgFemale = dataset2.loc[dataset2['Gender'] == 'Female'].mean()

# %%
AvgFemale
# Out:
# Age                           37.329932
# DistanceFromHome               9.210884
# Education                      2.933673
# EnvironmentSatisfaction        2.721088
# JobInvolvement                 2.714286
# JobLevel                       2.117347
# JobSatisfaction                2.683673
# MonthlyIncome               6686.566327
# NumCompaniesWorked             2.812925
# PercentSalaryHike             15.197279
# PerformanceRating              3.159864
# RelationshipSatisfaction       2.681973
# StockOptionLevel               0.780612
# TotalWorkingYears             11.726190
# TrainingTimesLastYear          2.860544
# WorkLifeBalance                2.763605
# YearsAtCompany                 7.231293
# YearsInCurrentRole             4.413265
# YearsSinceLastPromotion        2.294218
# YearsWithCurrManager           4.256803
# dtype: float64

# %%
JobRoleCheck = dataset2["JobRole"].value_counts().plot(kind = 'pie', autopct = '%.2f')

# %% [markdown]
# There is 60% male and 40% female in this dataset. The average age of employee is 36.9. The average age for male is 36.65 while the average age for female is 37.33. For salary, females have a higher average salary compared to the males at 6686.57 while males only have an average salary of 6380.50.

# %% [markdown]
# Now we will delve deeper into the dataset and attempt to identify the reasoning behind organization attrition. Generally, employees leave their organization due to several reasons: Salary issues, difficulty working with superiors, bad work life balance, unsatisfactory with their job or poor workplace culture.

# %%
ax1 = sns.countplot(x = 'Gender', hue = "Attrition", data = dataset2)
plt.title("Attrition rate between Gender")
for label in ax1.containers:
    labels = [f'{h/dataset2.Attrition.count()*100:0.1f}%' if (h := v.get_height()) > 0 else '' for v in label]
    ax1.bar_label(label, labels=labels, label_type='edge')

# %%
ax2 = sns.countplot(y = 'JobRole', hue = 'Attrition', data=dataset2)
plt.title("Attrition rate between Job Role")
for label in ax2.containers:
    labels = [f'{h/dataset2.Attrition.count()*100:0.1f}%' if (h := v.get_width()) > 0 else '' for v in label]
    ax2.bar_label(label, labels=labels, label_type='edge')

# %%
ax3 = sns.countplot(y = 'JobRole', hue = 'WorkLifeBalance', data=dataset2)
plt.title("Work Life Balance in each role")
for label in ax3.containers:
    labels = [f'{h/dataset2.WorkLifeBalance.count()*100:0.1f}%' if (h := v.get_width()) > 0 else '' for v in label]
    ax3.bar_label(label, labels=labels, label_type='edge')

# %%
ax5 = sns.countplot(y = 'JobRole', hue = 'JobSatisfaction', data=dataset2)
plt.title("Job satisfaction in each role")
for label in ax5.containers:
    labels = [f'{h/dataset2.EnvironmentSatisfaction.count()*100:0.1f}%' if (h := v.get_width()) > 0 else '' for v in label]
    ax5.bar_label(label, labels=labels, label_type='edge')

# %%
ax6 = sns.countplot(y = 'JobRole', hue = 'RelationshipSatisfaction', data=dataset2)
plt.title("Relationship satisfaction in each role")
for label in ax6.containers:
    labels = [f'{h/dataset2.RelationshipSatisfaction.count()*100:0.1f}%' if (h := v.get_width()) > 0 else '' for v in label]
    ax6.bar_label(label, labels=labels, label_type='edge')

# %%
ax4 = sns.countplot(x = 'Education', hue = 'Attrition', data=dataset2)
plt.title("Attrition between Education")
for label in ax4.containers:
    labels = [f'{h/dataset2.Attrition.count()*100:0.1f}%' if (h := v.get_height()) > 0 else '' for v in label]
    ax4.bar_label(label, labels=labels, label_type='edge')

# %%
ax7 = sns.histplot(x = 'MonthlyIncome', hue = 'Attrition', multiple= "dodge", bins= 30, data=dataset2)
plt.title("Histogram for Monthly income")
# Out:
# Text(0.5, 1.0, 'Histogram for Monthly income')

# %% [markdown]
# The organization attrition rate is 16.1% which means that 83.9% of the employees did not choose to leave the organization. Males have the highest attrition rate at 10.2%. Comparing education level, it would seems that bachelor employees have higher attrition rate compared to other education levels.
#
# Attrition between Job Role : Sales Representive, Lab Technician and Human Resources have the highest attrition rate compared to the other roles available within the organization. It is concerning and should be looked into why the attrition rate in these roles are significantly higher.
# Looking at the work life balance, it does not appear that work life balance is a major factor as employees are generally happy with the work life balance.
#
# Job and environment satisfaction could have played a part in the organization attrition rate as the number for low satisfaction are of a considerable amount (around 19.7% and 18.7% of the employee finds job and environment satisfaction to be low respectively.)
#
# From the salary histogram, we can deduce that employees with lower monthly income (<5k) do not tend to stay in the company whereas employees with higher monthly income (>15k) are happy with their salary.

# %% [markdown]
# In conclusion, organization attrition rate can be reduced by improving the job and workplace culture within the organization. Ensuring that employees in the organization have benefits to motivate them and know that their well-being is being taken care of.
